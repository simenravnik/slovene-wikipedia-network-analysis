# %%
import json
from sklearn.feature_extraction.text import TfidfVectorizer
import networkx as nx
import numpy as np
from helper_functions import read_net
import multiprocessing

# %%
with open("data/wikilinks.json", "r") as f:
    data = json.loads(f.read())

with open("data/title_to_id_map.json", "r") as f:
    title_to_id_map = json.loads(f.read())

with open("data/id_to_title_map.json", "r") as f:
    id_to_title_map = json.loads(f.read())

with open("data/summaries_all.json", "r") as f:
    summaries = json.loads(f.read())

# %%
G = read_net("data", "wikilinks_ids")

# %%
pageid_to_id_map = dict()
for node, label in G.nodes(data=True):
    pageid_to_id_map[label["label"]] = node

# %%
summaries_list = list(summaries.values())
tfidf = TfidfVectorizer().fit_transform(summaries_list)

# %%
idx_to_id_map = dict()
id_to_idx_map = dict()
for idx, id in enumerate(list(summaries.keys())):
    idx_to_id_map[idx] = id
    id_to_idx_map[id] = idx

# %%
edge_from = []
edge_to = []
for i in range(10):
    pairwise_similarity = tfidf[i] * tfidf.T
    similarity_vector = pairwise_similarity.toarray()[0][i+1:]

    idxs = np.where(similarity_vector > 0.35)[0]

    edge_from.extend([i]*len(idxs))
    edge_to.extend(list(idxs+i+1))

# %%
edge_to
# Out:
# [30,
#  884,
#  2603,
#  2721,
#  3241,
#  4762,
#  5222,
#  5883,
#  6181,
#  7443,
#  7563,
#  7702,
#  8782,
#  9081,
#  11182,
#  12821,
#  14082,
#  14943,
#  15181,
#  16262,
#  16427,
#  17262,
#  19448,
#  19666,
#  20526,
#  21562,
#  21781,
#  22860,
#  25405,
#  27181,
#  28341,
#  28746,
#  29300,
#  29341,
#  29529,
#  30225,
#  30282,
#  32900,
#  33321,
#  34990,
#  35001,
#  35262,
#  36263,
#  37182,
#  39464,
#  40444,
#  43445,
#  44302,
#  45607,
#  45623,
#  46641,
#  46741,
#  48781,
#  49947,
#  51260,
#  51580,
#  52161,
#  53031,
#  53061,
#  53681,
#  53722,
#  54566,
#  56160,
#  57122,
#  57244,
#  58721,
#  58964,
#  59640,
#  59947,
#  60524,
#  60780,
#  62340,
#  62583,
#  62622,
#  62800,
#  65193,
#  67620,
#  68385,
#  68602,
#  70243,
#  71324,
#  71822,
#  73320,
#  74820,
#  75284,
#  75403,
#  75685,
#  76624,
#  77904,
#  78153,
#  78423,
#  79402,
#  79983,
#  80204,
#  80682,
#  81482,
#  82281,
#  82443,
#  83064,
#  83101,
#  83982,
#  84756,
#  86322,
#  88222,
#  88545,
#  88583,
#  90445,
#  91341,
#  92962,
#  93740,
#  95124,
#  98841,
#  99160,
#  100792,
#  101363,
#  102385,
#  103192,
#  103705,
#  103803,
#  105162,
#  105241,
#  105520,
#  106502,
#  109987,
#  110621,
#  112321,
#  112760,
#  112822,
#  114203,
#  114489,
#  114546,
#  114881,
#  115190,
#  116904,
#  117626,
#  119202,
#  120362,
#  121401,
#  121782,
#  122142,
#  122192,
#  122661,
#  123840,
#  124764,
#  125002,
#  126440,
#  127541,
#  127784,
#  128243,
#  128401,
#  128864,
#  129423,
#  129601,
#  130382,
#  130526,
#  131581,
#  131701,
#  131922,
#  132865,
#  134012,
#  134181,
#  135362,
#  136302,
#  136682,
#  136801,
#  136923,
#  137922,
#  137923,
#  138680,
#  139407,
#  141502,
#  142003,
#  142388,
#  143002,
#  143487,
#  143928,
#  144303,
#  144323,
#  144605,
#  145040,
#  146501,
#  148240,
#  148527,
#  148762,
#  149934,
#  150147,
#  150641,
#  150921,
#  152182,
#  154483,
#  156328,
#  156482,
#  157808,
#  158825,
#  160442,
#  160902,
#  161644,
#  162821,
#  164845,
#  165174,
#  166802,
#  168600,
#  169892,
#  172202,
#  173300,
#  173636,
#  175523,
#  2902,
#  3023,
#  15262,
#  17482,
#  17823,
#  19402,
#  33182,
#  42442,
#  60823,
#  64562,
#  72343,
#  72681,
#  76506,
#  77444,
#  83920,
#  89063,
#  91503,
#  101222,
#  101984,
#  107901,
#  112686,
#  127586,
#  131902,
#  149904,
#  151545,
#  152370,
#  152823,
#  155702,
#  159384,
#  160244,
#  170504,
#  171521,
#  2061,
#  38347,
#  50388,
#  60322,
#  71866,
#  93808,
#  102883,
#  121026,
#  122303,
#  128123,
#  162084,
#  175491,
#  74675,
#  84,
#  755,
#  1688,
#  1889,
#  2030,
#  2391,
#  2529,
#  2670,
#  3010,
#  4729,
#  6728,
#  7371,
#  8009,
#  8610,
#  9085,
#  9888,
#  9926,
#  10368,
#  10511,
#  10512,
#  10809,
#  10987,
#  11171,
#  11568,
#  11888,
#  12154,
#  13129,
#  13272,
#  13572,
#  14010,
#  14368,
#  15051,
#  15207,
#  16190,
#  16293,
#  17250,
#  18069,
#  18111,
#  18690,
#  19952,
#  20212,
#  20869,
#  21169,
#  21468,
#  22305,
#  23146,
#  23546,
#  23747,
#  24868,
#  25009,
#  25169,
#  25812,
#  25813,
#  25848,
#  26007,
#  27147,
#  27329,
#  27869,
#  28872,
#  30867,
#  31090,
#  31291,
#  31933,
#  32232,
#  32409,
#  32550,
#  33130,
#  33533,
#  33929,
#  34105,
#  34771,
#  34865,
#  36145,
#  36592,
#  36647,
#  38168,
#  38272,
#  40765,
#  41012,
#  41366,
#  41548,
#  41972,
#  42549,
#  45030,
#  45467,
#  46152,
#  47807,
#  48290,
#  48849,
#  49212,
#  51285,
#  51647,
#  51771,
#  52568,
#  53229,
#  53507,
#  53888,
#  55046,
#  55529,
#  55810,
#  56153,
#  58791,
#  59346,
#  59811,
#  60050,
#  61428,
#  61949,
#  61950,
#  62028,
#  62648,
#  62868,
#  63229,
#  64212,
#  64249,
#  64469,
#  65027,
#  65772,
#  66071,
#  66231,
#  66269,
#  66373,
#  66870,
#  67132,
#  67630,
#  67631,
#  71892,
#  72212,
#  72230,
#  72470,
#  72988,
#  73086,
#  73088,
#  73128,
#  73152,
#  73589,
#  74307,
#  74688,
#  75327,
#  75832,
#  75851,
#  76151,
#  76630,
#  77309,
#  77867,
#  79169,
#  79747,
#  79788,
#  79809,
#  79949,
#  80772,
#  81289,
#  81368,
#  81509,
#  81628,
#  81648,
#  81789,
#  82289,
#  83167,
#  83230,
#  84811,
#  85672,
#  86008,
#  86110,
#  86408,
#  87212,
#  87332,
#  89169,
#  89188,
#  89390,
#  89470,
#  89769,
#  90791,
#  90868,
#  91071,
#  91511,
#  91572,
#  91971,
#  92188,
#  92289,
#  92611,
#  93245,
#  94389,
#  95210,
#  95972,
#  96393,
#  96489,
#  96608,
#  97653,
#  97893,
#  98488,
#  98729,
#  98847,
#  98907,
#  99529,
#  99710,
#  99788,
#  100987,
#  101189,
#  101830,
#  102447,
#  103187,
#  104129,
#  104709,
#  105150,
#  105209,
#  106591,
#  106748,
#  106990,
#  107008,
#  107991,
#  108148,
#  108329,
#  109492,
#  109493,
#  110040,
#  110108,
#  111068,
#  111111,
#  113509,
#  113609,
#  113649,
#  114066,
#  114551,
#  114568,
#  114869,
#  115108,
#  115426,
#  115751,
#  116709,
#  117247,
#  117766,
#  117792,
#  118189,
#  118810,
#  120530,
#  120650,
#  120988,
#  122353,
#  123167,
#  123170,
#  123965,
#  124089,
#  124487,
#  125008,
#  125248,
#  126208,
#  127233,
#  127307,
#  129871,
#  130272,
#  130311,
#  130707,
#  130909,
#  131208,
#  132088,
#  132110,
#  132752,
#  132848,
#  133949,
#  134209,
#  134493,
#  134528,
#  134848,
#  135688,
#  136131,
#  136244,
#  136524,
#  136592,
#  136628,
#  138091,
#  138973,
#  139568,
#  139868,
#  140451,
#  140809,
#  141288,
#  142210,
#  142711,
#  142951,
#  143589,
#  144669,
#  144926,
#  145613,
#  148247,
#  148248,
#  148747,
#  149227,
#  149691,
#  150050,
#  151090,
#  151186,
#  151268,
#  151749,
#  151831,
#  151988,
#  152208,
#  152948,
#  154348,
#  155766,
#  155986,
#  157627,
#  158489,
#  159169,
#  160165,
#  161027,
#  161070,
#  161750,
#  163646,
#  163845,
#  164170,
#  164569,
#  165373,
#  165611,
#  165872,
#  166069,
#  166411,
#  166511,
#  166887,
#  167510,
#  168469,
#  168769,
#  169245,
#  169506,
#  170188,
#  170846,
#  171348,
#  171468,
#  171528,
#  171707,
#  172248,
#  172830,
#  173831,
#  173971,
#  174231,
#  174290,
#  174329,
#  174349,
#  174970,
#  175306,
#  175933]
